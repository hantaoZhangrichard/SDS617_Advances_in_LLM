# %% [markdown]
# # S&DS 617 Advances in Large Language Models: Theory and Applications: Assignment 3
#
# **Deadline**
#
# Assignment 3 is due Monday, April 7th at 1:30pm.
#
# **Submission**
#
# Submit your assignment as a .pdf on Gradescope. On Gradescope, there are 2 assignments, one where you will submit a pdf file and one where you will submit the corresponding .ipynb that generated it.
# Note: The problems in each homework assignment are numbered. When submitting the pdf on Gradescope, please select the correct pages that correspond to each problem.
#
# To produce the .pdf, do the following to preserve the cell structure of the notebook:
# - Go to "File" at the top-left of your Jupyter Notebook
# - Under "Download as", select "HTML (.html)"
# - After the .html has downloaded, open it and then select "File" and "Print"
# - From the print window, select the option to save as a .pdf

# %% [markdown]
# In this assignment, we will fine-tune BERT using LoRA on the Yelp reviews dataset to predict whether a review is positive or negative. Some starter code has been provided to you below.

# %% [markdown]
# ### Load data

# %%
# Uncomment to install relevant packages if not already installed
# !pip install transformers
# !pip install torch torchvision
# !pip install datasets
# !pip install huggingface_hub
# !pip install peft==0.4.0 accelerate==0.26.0
# Out:
# Requirement already satisfied: transformers in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (4.49.0)
# Requirement already satisfied: filelock in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (0.29.0)
# Requirement already satisfied: numpy>=1.17 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (0.4.4)
# Requirement already satisfied: tqdm>=4.27 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->transformers) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: torch in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (2.5.1)
# Collecting torchvision
#   Downloading torchvision-0.21.0-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 3.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: filelock in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: sympy==1.13.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from torchvision) (1.26.4)
# Collecting torch
#   Downloading torch-2.6.0-cp311-none-macosx_11_0_arm64.whl (66.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 MB 3.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1
#     Uninstalling torch-2.5.1:
#       Successfully uninstalled torch-2.5.1
# Successfully installed torch-2.6.0 torchvision-0.21.0
# Requirement already satisfied: datasets in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (2.19.1)
# Requirement already satisfied: filelock in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from datasets) (14.0.2)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: multiprocess in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from datasets) (0.29.0)
# Requirement already satisfied: packaging in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets) (1.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: huggingface_hub in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (0.29.0)
# Requirement already satisfied: filelock in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from huggingface_hub) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from huggingface_hub) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from huggingface_hub) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->huggingface_hub) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->huggingface_hub) (2024.8.30)
# Collecting peft==0.4.0
#   Downloading peft-0.4.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 4.3 MB/s eta 0:00:00
# Collecting accelerate==0.26.0
#   Downloading accelerate-0.26.0-py3-none-any.whl (270 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.7/270.7 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from peft==0.4.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from peft==0.4.0) (24.1)
# Requirement already satisfied: psutil in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from peft==0.4.0) (5.9.0)
# Requirement already satisfied: pyyaml in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from peft==0.4.0) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from peft==0.4.0) (2.6.0)
# Requirement already satisfied: transformers in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from peft==0.4.0) (4.49.0)
# Requirement already satisfied: safetensors in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from peft==0.4.0) (0.4.4)
# Requirement already satisfied: huggingface-hub in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from accelerate==0.26.0) (0.29.0)
# Requirement already satisfied: filelock in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from torch>=1.13.0->peft==0.4.0) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from torch>=1.13.0->peft==0.4.0) (4.11.0)
# Requirement already satisfied: networkx in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from torch>=1.13.0->peft==0.4.0) (3.3)
# Requirement already satisfied: jinja2 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from torch>=1.13.0->peft==0.4.0) (3.1.4)
# Requirement already satisfied: fsspec in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from torch>=1.13.0->peft==0.4.0) (2024.3.1)
# Requirement already satisfied: sympy==1.13.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from torch>=1.13.0->peft==0.4.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from sympy==1.13.1->torch>=1.13.0->peft==0.4.0) (1.3.0)
# Requirement already satisfied: requests in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from huggingface-hub->accelerate==0.26.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from huggingface-hub->accelerate==0.26.0) (4.66.5)
# Requirement already satisfied: regex!=2019.12.17 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers->peft==0.4.0) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers->peft==0.4.0) (0.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.13.0->peft==0.4.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate==0.26.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate==0.26.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate==0.26.0) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate==0.26.0) (2024.8.30)
# Installing collected packages: accelerate, peft
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.4.0
#     Uninstalling accelerate-1.4.0:
#       Successfully uninstalled accelerate-1.4.0
# Successfully installed accelerate-0.26.0 peft-0.4.0

# %%
# !pip install --upgrade transformers
# Out:
# Requirement already satisfied: transformers in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (4.49.0)
# Collecting transformers
#   Downloading transformers-4.50.3-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 504.6 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: filelock in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (0.29.0)
# Requirement already satisfied: numpy>=1.17 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (0.4.4)
# Requirement already satisfied: tqdm>=4.27 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->transformers) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zhanghantao/anaconda3/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.49.0
#     Uninstalling transformers-4.49.0:
#       Successfully uninstalled transformers-4.49.0
# Successfully installed transformers-4.50.3

# %%
import datasets
import requests, tarfile, os
import torch
import pandas as pd
from torch.utils.data import DataLoader, Dataset
from peft import LoraConfig, TaskType, get_peft_model
from transformers import BertTokenizer, BertForSequenceClassification, TrainingArguments, Trainer
import numpy as np
from sklearn.metrics import roc_auc_score

# %%
# URL of the Yelp reviews dataset
_DOWNLOAD_URL = "https://s3.amazonaws.com/fast-ai-nlp/yelp_review_polarity_csv.tgz"

# Function to download and extract the dataset
def download_and_extract_dataset(url):
    # Download the dataset
    local_file = "yelp_review_polarity_csv.tgz"
    response = requests.get(url)
    open(local_file, 'wb').write(response.content)

    # Extract the dataset
    tar = tarfile.open(local_file, "r:gz")
    tar.extractall()
    tar.close()

# Function to load the dataset into pandas DataFrame
def load_dataset():
    # Download and extract if dataset directory doesn't exist
    if not os.path.exists("yelp_review_polarity_csv"):
        download_and_extract_dataset(_DOWNLOAD_URL)

    # Load train and test datasets
    train_data = pd.read_csv("yelp_review_polarity_csv/train.csv", header=None, names=["label", "text"])
    test_data = pd.read_csv("yelp_review_polarity_csv/test.csv", header=None, names=["label", "text"])
    
    # Subsample down
    train_data = train_data.sample(n=5000, random_state=11)
    test_data = test_data.sample(n=1000, random_state=94)
    
    # Adjust labels to be zero-based if necessary
    train_data['label'] -= 1
    test_data['label'] -= 1

    return train_data, test_data

# Load the data
train_data, test_data = load_dataset()

# Display the first few rows of the train and test sets
print(train_data.head())
print(test_data.head())
# Out:
#         label                                               text
# 478660      0  Not a good place. WAY over proceed for what it...
# 330978      1  They have the best cocktails! They are all mad...
# 473311      1  Great pizza. The owner use to work for metro s...
# 320559      1  Wow. What a great show!\n\nThere are several d...
# 526693      0  Me and my boyfriend started coming here after ...
#        label                                               text
# 9423       1  Dirty martinis with blue cheese olives!!!!!!!!...
# 29439      0  My husband had gone to a different location th...
# 7064       1  Very tasty food! The lady's offer prompt and s...
# 18986      0  Very so so burgers. Best to head elsewhere for...
# 16556      0  As a New Yorker, I was looking forward to tryi...

# %%
train_data.iloc[0]['text']
# Out:
# 'Not a good place. WAY over proceed for what it is, just a COMPLETE waste of time. Just go ANYWHERE else'

# %%
# Load the tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Dataset class for Yelp Polarity Reviews
class YelpPolarityReviewDataset(Dataset):
    def __init__(self, data, tokenizer, max_len):
        self.data = data
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Check if the index is valid
        if idx < 0 or idx >= len(self.data):
            raise IndexError(f"Index {idx} is out of bounds for dataset with length {len(self.data)}")
        review = self.data.iloc[idx]['text']
        label = self.data.iloc[idx]['label']
        encoding = self.tokenizer.encode_plus(
            review,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt'
        )
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

# Create datasets
max_len = 128
train_dataset = YelpPolarityReviewDataset(train_data, tokenizer, max_len)
test_dataset = YelpPolarityReviewDataset(test_data, tokenizer, max_len)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32)

# %%
lora_config = LoraConfig(
    task_type=TaskType.SEQ_CLS, r=1, lora_alpha=1, lora_dropout=0.1
)

model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

model = get_peft_model(model, lora_config)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Function to compute AUC for binary classification
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    # Convert to probabilities using sigmoid (since it's binary classification)
    probs = np.exp(logits) / (1 + np.exp(logits))
    # For binary classification, use the probabilities of the positive class (assumed to be at index 1)
    probs = probs[:, 1]
    # Calculate AUC
    auc = roc_auc_score(labels, probs)
    return {"auc": auc}

# Training arguments
training_args = TrainingArguments(
    output_dir="test_trainer",
    evaluation_strategy="epoch",
    num_train_epochs=15,
)

# Initialize the Trainer
trainer = Trainer(
    model=model, 
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics,
)

# Start training
trainer.train()
# Out:
# /Users/zhanghantao/anaconda3/lib/python3.11/site-packages/transformers/training_args.py:1611: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# No label_names provided for model class `PeftModelForSequenceClassification`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
#     <div>
#
#       <progress value='9375' max='9375' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9375/9375 4:08:53, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.667900</td>
#       <td>0.545021</td>
#       <td>0.821097</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.497100</td>
#       <td>0.327098</td>
#       <td>0.936059</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.353200</td>
#       <td>0.314753</td>
#       <td>0.950798</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.302400</td>
#       <td>0.296714</td>
#       <td>0.956203</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.301400</td>
#       <td>0.300503</td>
#       <td>0.958212</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.282900</td>
#       <td>0.283367</td>
#       <td>0.960604</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.281200</td>
#       <td>0.288458</td>
#       <td>0.961805</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.278600</td>
#       <td>0.284383</td>
#       <td>0.963149</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.268900</td>
#       <td>0.280952</td>
#       <td>0.964021</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.287500</td>
#       <td>0.283177</td>
#       <td>0.964697</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.269600</td>
#       <td>0.282461</td>
#       <td>0.965021</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.269700</td>
#       <td>0.283125</td>
#       <td>0.965481</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.264000</td>
#       <td>0.280141</td>
#       <td>0.965649</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.275400</td>
#       <td>0.280569</td>
#       <td>0.965729</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.263300</td>
#       <td>0.282131</td>
#       <td>0.965845</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=9375, training_loss=0.31794892008463543, metrics={'train_runtime': 14936.8093, 'train_samples_per_second': 5.021, 'train_steps_per_second': 0.628, 'total_flos': 4935544243200000.0, 'train_loss': 0.31794892008463543, 'epoch': 15.0})

# %% [markdown]
# ## Problem 1: Comparison of Trainable Parameters
# Compare the total number of trainable parameters between the standard fine-tuning approach and the Low-Rank Adaptation (LoRA) method. Detail how LoRA alters the model’s parameter complexity compared to traditional fine-tuning. Discuss the implications of these changes on the model's training efficiency, accuracy, and computational demand. Consider including a discussion on parameter sharing and model capacity in your answer. Under what scenarios might one method be preferred over the other, considering factors such as available computational resources, the complexity of the task, and dataset size?

# %% [markdown]
# ## Problem 2: Hyperparameter Experimentation with LoRA
# In your experimentation with the LoRA configuration, document the process and present your findings in a structured manner. Describe the specific LoRA hyperparameters you adjusted, including the rank (`r`) and the learning rate scale (`lora_alpha`). Test a range of values for each and analyze how changing these hyperparameters affects the model's performance in terms of training convergence speed and final model accuracy. Provide graphs or tables to support your findings
